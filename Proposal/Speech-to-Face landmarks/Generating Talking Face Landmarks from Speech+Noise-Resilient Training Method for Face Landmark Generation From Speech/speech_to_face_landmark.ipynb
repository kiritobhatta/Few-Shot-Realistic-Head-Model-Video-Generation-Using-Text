# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
cd /content/gdrive/My Drive/Colab_Notebooks/noise_resilient_3dtface-master
# Out:
# /content/gdrive/My Drive/Colab_Notebooks/noise_resilient_3dtface-master

# %%
pip install -r requirements.txt
# Out:
# Collecting audioread==2.1.6
#   Using cached https://files.pythonhosted.org/packages/f0/41/8cd160c6b2046b997d571a744a7f398f39e954a62dd747b2aae1ad7f07d4/audioread-2.1.6.tar.gz
# Collecting backports.functools-lru-cache==1.5
#   Using cached https://files.pythonhosted.org/packages/03/8e/2424c0e65c4a066e28f539364deee49b6451f8fcd4f718fefa50cc3dcf48/backports.functools_lru_cache-1.5-py2.py3-none-any.whl
# Collecting certifi==2019.3.9
#   Using cached https://files.pythonhosted.org/packages/60/75/f692a584e85b7eaba0e03827b3d51f45f571c2e793dd731e598828d380aa/certifi-2019.3.9-py2.py3-none-any.whl
# Collecting cffi==1.12.3
#   Using cached https://files.pythonhosted.org/packages/5f/bf/6aa1925384c23ffeb579e97a5569eb9abce41b6310b329352b8252cee1c3/cffi-1.12.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting cloudpickle==0.8.1
#   Using cached https://files.pythonhosted.org/packages/6e/bc/67f13115adcce4efc5e4d7f8220fb9a50aaa2b5c7ed460b26cbb76aa76ad/cloudpickle-0.8.1-py2.py3-none-any.whl
# Collecting cpbd==1.0.7
#   Using cached https://files.pythonhosted.org/packages/5e/2c/fbe38a67ef376c6ddf1a07e06f17cc7fed89342aa586fe59ff73671e1397/cpbd-1.0.7.tar.gz
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (0.10.0)
# Collecting dask==1.2.0
#   Using cached https://files.pythonhosted.org/packages/67/a2/0f0e777400f8288e808556610036a92026759869a43b582203e977342637/dask-1.2.0-py2.py3-none-any.whl
# Collecting decorator==4.4.0
#   Using cached https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl
# Collecting dlib==19.17.0
#   Using cached https://files.pythonhosted.org/packages/05/57/e8a8caa3c89a27f80bc78da39c423e2553f482a3705adc619176a3a24b36/dlib-19.17.0.tar.gz
# Collecting enum34==1.1.6
#   Using cached https://files.pythonhosted.org/packages/af/42/cb9355df32c69b553e72a2e28daee25d1611d2c0d9c272aa1d34204205b2/enum34-1.1.6-py3-none-any.whl
# Collecting funcsigs==1.0.2
#   Using cached https://files.pythonhosted.org/packages/69/cb/f5be453359271714c01b9bd06126eaf2e368f1fddfff30818754b5ac2328/funcsigs-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 13)) (2.10.0)
# Collecting joblib==0.13.2
#   Using cached https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl
# Collecting kiwisolver==1.0.1
#   Using cached https://files.pythonhosted.org/packages/69/a7/88719d132b18300b4369fbffa741841cfd36d1e637e1990f27929945b538/kiwisolver-1.0.1-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: librosa==0.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 16)) (0.6.3)
# Collecting llvmlite==0.28.0
#   Using cached https://files.pythonhosted.org/packages/b5/f3/6d7f49db45df0276166f99723aa10310862a3783556cd284793da478afed/llvmlite-0.28.0-1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting matplotlib==2.2.4
#   Using cached https://files.pythonhosted.org/packages/48/9b/7ee428ab95b07946d5c20ba01ce27721686e6051b202930d3d810821c166/matplotlib-2.2.4-cp36-cp36m-manylinux1_x86_64.whl
# ERROR: Could not find a version that satisfies the requirement mkl-fft==1.0.10 (from -r requirements.txt (line 19)) (from versions: 1.0.0.17, 1.0.2, 1.0.6)
# ERROR: No matching distribution found for mkl-fft==1.0.10 (from -r requirements.txt (line 19))

# %%
pip install mkl-fft
# Out:
# Requirement already satisfied: mkl-fft in /usr/local/lib/python3.6/dist-packages (1.0.6)
# Requirement already satisfied: intel-numpy in /usr/local/lib/python3.6/dist-packages (from mkl-fft) (1.15.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.6/dist-packages (from intel-numpy->mkl-fft) (2019.0)
# Requirement already satisfied: mkl-random in /usr/local/lib/python3.6/dist-packages (from intel-numpy->mkl-fft) (1.0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.6/dist-packages (from intel-numpy->mkl-fft) (2019.0)
# Requirement already satisfied: icc-rt in /usr/local/lib/python3.6/dist-packages (from intel-numpy->mkl-fft) (2020.0.133)
# Requirement already satisfied: tbb==2019.* in /usr/local/lib/python3.6/dist-packages (from tbb4py->intel-numpy->mkl-fft) (2019.0)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.6/dist-packages (from mkl->intel-numpy->mkl-fft) (2020.0.133)

# %%
import subprocess

# %%
from time import time

# %%
# %cd /content/gdrive/My Drive/Colab_Notebooks/noise_resilient_3dtface-master/code
# Out:
# /content/gdrive/My Drive/Colab_Notebooks/noise_resilient_3dtface-master/code

# %%
t0 = time()
# !python generate.py -i ../speech_samples/ -m ../pre_trained/1D_CNN.pt -o ../results/1D_CNN/
t1 = time()
# Out:
# ../speech_samples/test1.flac
# 100% 375/375 [00:38<00:00,  9.86it/s]
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../results/1D_CNN/test1_painted.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Movie Test
#     artist          : Matplotlib
#     encoder         : Lavf57.83.100
#     comment         : Movie support!
#   Duration: 00:00:15.00, start: 0.000000, bitrate: 423 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1000x1000, 420 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '../results/1D_CNN/test1_painted.wav':
#   Duration: 00:00:15.00, bitrate: 705 kb/s
#     Stream #1:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 22050 Hz, mono, flt, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (pcm_f32le (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to '../results/1D_CNN/test1_painted_.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Movie Test
#     artist          : Matplotlib
#     comment         : Movie support!
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1000x1000, q=2-31, 420 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc57.107.100 aac
# frame=  375 fps=0.0 q=-1.0 Lsize=     914kB time=00:00:15.00 bitrate= 499.2kbits/s speed=55.2x
# video:770kB audio:133kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.195964%
# [aac @ 0x55ac96465700] Qavg: 1243.746

# %%
from IPython.display import HTML
from base64 import b64encode
print("Generation time : %fs" %(t1-t0))
mp4 = open('/content/gdrive/My Drive/Colab_Notebooks/noise_resilient_3dtface-master/results/1D_CNN/test1_painted_.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
#t2= time()

#print("Generation time: %fs" %(t1-t0))
#print("Display result time: %fs" %(t2-t1))
#print("Total time: %fs" %(t2-t0))
# Out:
# Generation time : 47.082313s
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# %cd /content/gdrive/My Drive/Colab_Notebooks/Talking-Face-Landmarks-from-Speech-master
# Out:
# /content/gdrive/My Drive/Colab_Notebooks/Talking-Face-Landmarks-from-Speech-master

# %%
pip install opencv-python==3.4.2.16
# Out:
# Collecting opencv-python==3.4.2.16
#   Downloading https://files.pythonhosted.org/packages/fa/7d/5042b668a8ed41d2a80b8c172f5efcd572e3c046c75ae029407e19b7fc68/opencv_python-3.4.2.16-cp36-cp36m-manylinux1_x86_64.whl (25.0MB)
#      |████████████████████████████████| 25.0MB 129kB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.2.16) (1.18.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-3.4.2.16

# %%
t0 = time()
# !python generate.py -i test_samples/test1.flac -m models/D40_C3.h5 -d 1 -c 3 -o results/D40_C3_test1
t1 = time()
# Out:
# 2020-09-10 20:08:09.967713: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-10 20:08:12.359677: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-10 20:08:12.383597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.384226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-09-10 20:08:12.384270: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-10 20:08:12.384342: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-10 20:08:12.385982: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-09-10 20:08:12.386069: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-09-10 20:08:12.386131: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-09-10 20:08:12.387367: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-09-10 20:08:12.387464: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-10 20:08:12.387624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.388307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.388877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-09-10 20:08:12.394920: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-09-10 20:08:12.395157: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5059f80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-10 20:08:12.395196: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-10 20:08:12.497303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.497897: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x505a140 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-09-10 20:08:12.497933: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-09-10 20:08:12.498169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.498593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-09-10 20:08:12.498642: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-10 20:08:12.498725: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-10 20:08:12.498758: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-09-10 20:08:12.498789: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-09-10 20:08:12.498812: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-09-10 20:08:12.498835: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-09-10 20:08:12.498858: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-10 20:08:12.498990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.499474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:12.499858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-09-10 20:08:12.499915: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-10 20:08:13.183016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-10 20:08:13.183074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-09-10 20:08:13.183088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-09-10 20:08:13.183361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:13.183961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-10 20:08:13.184344: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-09-10 20:08:13.184388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6960 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 75, 512)]         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 75, 512)           2099200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 75, 512)           2099200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 75, 512)           2099200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 75, 136)           353056
# =================================================================
# Total params: 6,650,656
# Trainable params: 6,650,656
# Non-trainable params: 0
# _________________________________________________________________
#   0% 0/375 [00:00<?, ?it/s]2020-09-10 20:08:16.741541: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 100% 375/375 [00:47<00:00,  7.95it/s]
# Exp
# (375, 68, 2)
# 100% 375/375 [00:30<00:00, 12.18it/s]
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'results/D40_C3_test1/PD_pts.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Movie Test
#     artist          : Matplotlib
#     encoder         : Lavf57.83.100
#     comment         : Movie support!
#   Duration: 00:00:15.00, start: 0.000000, bitrate: 418 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1500x1500, 416 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from 'results/D40_C3_test1/PD_pts.wav':
#   Duration: 00:00:15.00, bitrate: 1411 kb/s
#     Stream #1:0: Audio: pcm_f32le ([3][0][0][0] / 0x0003), 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (pcm_f32le (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'results/D40_C3_test1/PD_pts_ws.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Movie Test
#     artist          : Matplotlib
#     comment         : Movie support!
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1500x1500, q=2-31, 416 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc57.107.100 aac
# frame=  375 fps=0.0 q=-1.0 Lsize=     909kB time=00:00:15.00 bitrate= 496.4kbits/s speed=41.1x
# video:762kB audio:133kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.524423%
# [aac @ 0x55bdc6a53700] Qavg: 239.065
# Muxing Done

# %%
from IPython.display import HTML
from base64 import b64encode
print("Generation time : %fs" %(t1-t0-48))
mp4 = open('/content/gdrive/My Drive/Colab_Notebooks/Talking-Face-Landmarks-from-Speech-master/results/D40_C3_test1/PD_pts_ws.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
#t2= time()

#print("Generation time: %fs" %(t1-t0))
#print("Display result time: %fs" %(t2-t1))
#print("Total time: %fs" %(t2-t0))
# Out:
# Generation time : 39.184405s
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
